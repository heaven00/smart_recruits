# %%
import pandas as pd
import seaborn as sb

# %%
# %matplotlib inline

# %%
data = pd.read_csv('data/Train_pjb2QcD.csv', low_memory=False)

# %%
for col in data.columns:
    print(col, data[col].isnull().values.sum())
# Out:
# ID 0
# Office_PIN 0
# Application_Receipt_Date 0
# Applicant_City_PIN 97
# Applicant_Gender 67
# Applicant_BirthDate 73
# Applicant_Marital_Status 73
# Applicant_Occupation 1221
# Applicant_Qualification 86
# Manager_DOJ 683
# Manager_Joining_Designation 683
# Manager_Current_Designation 683
# Manager_Grade 683
# Manager_Status 683
# Manager_Gender 683
# Manager_DoB 683
# Manager_Num_Application 683
# Manager_Num_Coded 683
# Manager_Business 683
# Manager_Num_Products 683
# Manager_Business2 683
# Manager_Num_Products2 683
# Business_Sourced 0

# %%
data[data['Manager_Status'].isnull()].count()
# Out:
# ID                             683
# Office_PIN                     683
# Application_Receipt_Date       683
# Applicant_City_PIN             666
# Applicant_Gender               669
# Applicant_BirthDate            669
# Applicant_Marital_Status       669
# Applicant_Occupation           552
# Applicant_Qualification        668
# Manager_DOJ                      0
# Manager_Joining_Designation      0
# Manager_Current_Designation      0
# Manager_Grade                    0
# Manager_Status                   0
# Manager_Gender                   0
# Manager_DoB                      0
# Manager_Num_Application          0
# Manager_Num_Coded                0
# Manager_Business                 0
# Manager_Num_Products             0
# Manager_Business2                0
# Manager_Num_Products2            0
# Business_Sourced               683
# dtype: int64

# %%
data.groupby(['Manager_Joining_Designation'])['Business_Sourced'].count().plot(kind='bar')

# %%
data.groupby(['Manager_Current_Designation'])['Business_Sourced'].count().plot(kind='bar')

# %%
data.groupby(['Manager_Current_Designation'])['Business_Sourced'].mean().plot(kind='bar')

# %%
data.groupby(['Manager_Grade'])['Business_Sourced'].mean().plot(kind='bar')

# %%
data.groupby(['Manager_Num_Application'])['Business_Sourced'].mean().plot(kind='bar')

# %%
data.groupby(['Manager_Num_Application'])['Business_Sourced'].mean().plot(kind='hist')

# %%
data.groupby(['Manager_Grade'])['Manager_Num_Application'].count().plot(kind='bar')

# %%
data.groupby(['Applicant_Occupation'])['Business_Sourced']().plot(kind='bar')

# %%
data.groupby(['Applicant_Occupation','Business_Sourced'])['ID'].count().plot(kind='bar', figsize=(18, 8), table=True, sort_columns=True)

# %%
data.groupby(['Applicant_Qualification','Business_Sourced'])['ID'].count().plot(kind='bar', figsize=(18, 8), table=True, sort_columns=True)

# %%
data.groupby(['Manager_Status'])['Business_Sourced'].mean().plot(kind='bar', figsize=(18, 8), table=True, sort_columns=True)
